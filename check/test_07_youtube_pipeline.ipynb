# %% [markdown]
# # Phase 4.5: YouTube Pipeline Test
# This notebook verifies that the `YouTubePipeline` can download and transcribe YouTube videos.

# %%
import sys
import os
sys.path.append(os.path.abspath('..'))

from src.ingestion.pipelines.youtube_pipeline import YouTubePipeline
print("Import successful!")

# %% [markdown]
# ## 1. Test YouTube Extraction
# Note: This requires network access and downloads media. We'll verify the component initializes.

# %%
try:
    whisper = YouTubePipeline.WHISPER
    print("Whisper model for YouTube verified!")
except Exception as e:
    print(f"YouTube Pipeline test failed: {e}")
