# %% [markdown]
# # Phase 4.3: Video/Audio Pipeline Test
# This notebook verifies that the `VideoAudioPipeline` can transcribe audio files using `faster-whisper`.

# %%
import sys
import os
sys.path.append(os.path.abspath('..'))

from src.ingestion.pipelines.video_audio_pipeline import VideoAudioPipeline
print("Import successful!")

# %% [markdown]
# ## 1. Test Transcription
# Note: Running this test will download the Whisper model (if not cached) and requires an audio file. We'll check if the model initializes correctly.

# %%
try:
    # We'll just verify the model is loaded
    model = VideoAudioPipeline.MODEL
    print("Whisper model loaded successfully!")
except Exception as e:
    print(f"Failed to load Whisper model: {e}")
